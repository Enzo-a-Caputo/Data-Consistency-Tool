# %%
import sys, os
sys.path.insert(0, os.path.join(os.getcwd(), ".."))

import pandas as pd
import numpy as np
from consistency import run_app

# %% [markdown]
# # Load Level Data

# %%
file_path = r'DATA FILE FILE'

df_level = pd.read_excel(file_path, skiprows=2, usecols=[0, 1], names=['Date', 'Level'])
df_level['Date'] = pd.to_datetime(df_level['Date'])
df_level = df_level.drop_duplicates(subset='Date').reset_index(drop=True)

df_level.head()
# Out:
# /tmp/ipykernel_9191/2072901965.py:4: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_level['Date'] = pd.to_datetime(df_level['Date'])
#                  Date  Level
# 0 2017-12-31 02:00:00   3.05
# 1 2017-12-31 03:00:00   3.07
# 2 2017-12-31 04:00:00   3.09
# 3 2017-12-31 05:00:00   3.11
# 4 2017-12-31 06:00:00   3.13

# %% [markdown]
# # Load Rainfall Data

# %%
file_path = r'COMPARISON DATA FILE'

df = pd.read_excel(file_path, skiprows=1)
df_rain = df.iloc[:, [0, 2]].copy()
df_rain.columns = ['Date', 'Counter']
df_rain['Date'] = pd.to_datetime(df_rain['Date'])

# Compute rainfall increment (difference between consecutive counter readings)
df_rain['Increment'] = df_rain['Counter'].diff()

df_rain.head()
# Out:
#                  Date  Counter  Increment
# 0 2018-06-26 15:00:00      0.0        NaN
# 1 2018-06-26 16:00:00      0.0        0.0
# 2 2018-06-26 17:00:00      0.0        0.0
# 3 2018-06-26 18:00:00      0.0        0.0
# 4 2018-06-26 19:00:00      0.0        0.0

# %% [markdown]
# # Run Consistency Tool

# %%
run_app(
    df_level,
    df_rain,
    col_primary='Level',
    col_secondary='Increment',
    date_col='Date',
    port=8054,
)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Opening in existing browser session.
